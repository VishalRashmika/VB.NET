# %%
import pandas as pd

# %%
df = pd.read_csv('./Tweets.csv')
df.shape
# Out:
# (14640, 15)

# %%
df.groupby('airline_sentiment').describe()
# Out:
#                   tweet_id                                            \
#                      count          mean           std           min
# airline_sentiment
# negative            9178.0  5.692602e+17  7.572474e+14  5.675900e+17
# neutral             3099.0  5.691841e+17  8.068405e+14  5.675883e+17
# positive            2363.0  5.691006e+17  8.112476e+14  5.676555e+17
#
#                                                                            \
#                             25%           50%           75%           max
# airline_sentiment
# negative           5.686511e+17  5.695355e+17  5.698798e+17  5.703106e+17
# neutral            5.684852e+17  5.693080e+17  5.699305e+17  5.703093e+17
# positive           5.684331e+17  5.691980e+17  5.698788e+17  5.703093e+17
#
#                   airline_sentiment_confidence            ...  \
#                                          count      mean  ...
# airline_sentiment                                         ...
# negative                                9178.0  0.933365  ...
# neutral                                 3099.0  0.823303  ...
# positive                                2363.0  0.872039  ...
#
#                   negativereason_confidence      retweet_count            \
#                                         75%  max         count      mean
# airline_sentiment
# negative                                1.0  1.0        9178.0  0.093375
# neutral                                 0.0  0.0        3099.0  0.060987
# positive                                0.0  0.0        2363.0  0.069403
#
#
#                         std  min  25%  50%  75%   max
# airline_sentiment
# negative           0.792865  0.0  0.0  0.0  0.0  44.0
# neutral            0.658037  0.0  0.0  0.0  0.0  28.0
# positive           0.659914  0.0  0.0  0.0  0.0  22.0
#
# [3 rows x 32 columns]

# %%
df = df.drop_duplicates(keep='first')
df.groupby('airline_sentiment').describe()
# Out:
#                   tweet_id                                            \
#                      count          mean           std           min
# airline_sentiment
# negative            9159.0  5.692581e+17  7.565777e+14  5.675900e+17
# neutral             3091.0  5.691813e+17  8.059167e+14  5.675883e+17
# positive            2354.0  5.690960e+17  8.094933e+14  5.676555e+17
#
#                                                                            \
#                             25%           50%           75%           max
# airline_sentiment
# negative           5.686488e+17  5.695339e+17  5.698776e+17  5.703106e+17
# neutral            5.684840e+17  5.693051e+17  5.699277e+17  5.703093e+17
# positive           5.684304e+17  5.691869e+17  5.698746e+17  5.703093e+17
#
#                   airline_sentiment_confidence            ...  \
#                                          count      mean  ...
# airline_sentiment                                         ...
# negative                                9159.0  0.933227  ...
# neutral                                 3091.0  0.822846  ...
# positive                                2354.0  0.871550  ...
#
#                   negativereason_confidence      retweet_count            \
#                                         75%  max         count      mean
# airline_sentiment
# negative                                1.0  1.0        9159.0  0.093460
# neutral                                 0.0  0.0        3091.0  0.061145
# positive                                0.0  0.0        2354.0  0.069669
#
#
#                         std  min  25%  50%  75%   max
# airline_sentiment
# negative           0.793619  0.0  0.0  0.0  0.0  44.0
# neutral            0.658881  0.0  0.0  0.0  0.0  28.0
# positive           0.661160  0.0  0.0  0.0  0.0  22.0
#
# [3 rows x 32 columns]
